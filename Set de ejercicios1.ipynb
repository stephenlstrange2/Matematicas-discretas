# %% [markdown]
# # Set de ejercicios
# ## Problema 1 (0.5 puntos)
# Realice la tabla de verdad y determine si es tautología, contradicción o
# contingencia
#
# ∼ [𝒑 ∧ (∼ 𝒑)]
#
#
# |p| ~p |𝒑 ∧ (∼ 𝒑)|∼ [𝒑 ∧ (∼ 𝒑)]|
# |-|----|---------|------------|
# |V| F  |    F    |      V     |
# |F| V  |    F    |      V     |
#
# ### RESPUESTA: TAUTOLOGIA

# %% [markdown]
# ## Problema 2 (0.5 puntos)
# Realice la tabla de verdad y determine si es tautología, contradicción o contingencia
#
# (𝒑 ∧ 𝒒) ⟹ 𝒑
#
#
# ¿Cuál es el número de combinaciones?
#
# | p | q | (𝒑 ∧ 𝒒) |(𝒑 ∧ 𝒒) ⟹ p |
# |---|---|---------|------------|
# | V | V |    V    |     V      |
# | V | F |    F    |     V      |
# | F | V |    F    |     V      |
# | F | F |    F    |     V      |
#
# ### RESPUESTA: TAUTOLOGIA

# %% [markdown]
# ## Problema 3 (2 puntos)
# Realice la tabla de verdad y determine si es tautología, contradicción o
# contingencia
#
# 𝒑 ∧ [(∼ 𝒑) ∧ (∼ 𝒒)]
#
#
# | ∼p | ∼q | ((∼𝒑) ∧ (∼𝒒)) |(((∼𝒑) ∧ (∼𝒒)) ∧ p)|
# |----|----|---------------|-------------------|
# | V  | V  |       V       |           F      |
# | V  | F  |       F       |           F      |
# | F  | V  |       F       |           F      |
# | F  | F  |       F       |           F      |
#
#
# ### RESPUESTA: CONTRADICCION

# %% [markdown]
# ## Problema 4 (1 puntos)
#
# Dadas las proposiciones:
#
# p: Oscar aprueba sus cursos
#
# q: Oscar va a la fiesta
#
# r: Oscar estudia para su examen
#
# **Simbolizar**
#
# “Si Oscar va a la fiesta entonces no estudiará para su examen, pero no es el
# caso que vaya a la fiesta y aprueba sus cursos. De ahí que Oscar estudia para
# su examen”
#
# **⟹**
#
# Si q entonces no r, pero no es el caso que q y p. por lo tanto r
#
# **⟹**
#
# ((q ⟹ ~r) ∧ ~( q ∧ p)) ⟹ r
#
# | p  |  q |  r   | (q ⟹ ~r)  |~( q ∧ p) | ((q ⟹ ~r) ∧ ~( q ∧ p)) | ((q ⟹ ~r) ∧ ~( q ∧ p)) ⟹ r|
# |----|----|------|------------|----------|--------------------------|------------------------------|
# | V  | V  |  V   |  F         |   F      |             F            |            F                 |
# | V  | V  |  F   |  V         |   F      |             F            |            V                 |
# | V  | F  |  V   |  V         |   V      |             V            |            V                 |
# | V  | F  |  F   |  V         |   V      |             V            |            F                 |
# | F  | V  |  V   |  F         |   V      |             V            |            V                 |
# | F  | V  |  F   |  V         |   V      |             V            |            F                 |
# | F  | F  |  V   |  V         |   V      |             V            |            V                 |
# | F  | F  |  F   |  V         |   V      |             V            |            F                 |
#
#
# ### RESPUESTA : CONTINGENCIA

# %% [markdown]
# ## Problema 5 (1 punto)
#
# Si p es verdadera, determinar el valor de verdad de ∼ 𝒑 ⟹ (𝒑 ∨ 𝒒)
#
# ∼ 𝒑 ⟹ (𝒑 ∨ 𝒒)
#
# | p | ~p | q | (𝒑 ∨ 𝒒) | ∼ 𝒑 ⟹ (𝒑 ∨ 𝒒)|
# |---|----|---|---------|--------------|
# | V |  F | V |    V    |     V        |
# | V |  F | F |    V    |     V        |
#
# ### RESULTADO: TAUTOLOGIA

# %% [markdown]
# ## Problema 6 (2 puntos)
#
# La proposición
#
# “Si no tomas en serio las cosas tendrás problemas para ingresar o no serás
# profesional”, es falsa.
#
#
# ¿Qué valor de verdad asume la proposición: “no tienes problemas para
# ingresar”
#
#     a) Verdadero
#
#     b) Falso
#
#     c) Contradictorio
#
#     d) Indeterminado
#
# **Consideremos:**
#
#     p: tomas en serio las cosas
#
#     q: tendrás problemas para ingresar
#
#     r: serás profesional
#
#
# **primero** analizamos la oracion *“Si no tomas en serio las cosas tendrás problemas para ingresar o no serás
# profesional”* y la componemos como una proposicion logica
#
#
#     R) si ~p entonces (q  V ~r)
#
# De antemano sabemos por definicion que esta oracion es falsa por lo tanto debemos encontrar los vamoles de p q y r para determinar este resultado
#
# **~p ⟹ (q V ~r)**
#
# <=>
#
# **~p = (Falso) <=> (q V ~r) = (Verdadero)**
#
# =>
#
# **p = (Verdadero)**
#
# =>
#
# ### Respuesta: Es falso que no tienes problemas para ingresar

# %% [markdown]
# ## problema 7 (3 puntos)
#
# Verificar la validez del siguiente argumento por la prueba formal de validez,
# dada su traducción lógica:
#
# Traducción lógica.
#
# (∼ 𝒉 ∨ 𝒊) ⟹ (𝒋 ⟹ 𝒌)
#
# (∼ 𝒍 ∧∼ 𝒎) ⟹ (𝒌 ⟹ 𝒏)
#
# (𝒉 ⟹ 𝒍) ∧ (𝒍 ⟹ 𝒉)
#
# (∼ 𝒍 ∧∼ 𝒎) ∧∼ 𝒄
#
# ∴ 𝒋 ⟹ 𝒏
#
# Organizar argumento.
#
#     1. (∼ 𝒉 ∨ 𝒊) ⟹ (𝒋 ⟹ 𝒌)
# (∼ 𝒉 ∨ 𝒊) ⟹ (𝒋 ⟹ 𝒌) **Vedadero**
#
# <=>
#
# {
# (∼ 𝒉 ∨ 𝒊) **Falso** y (𝒋 ⟹ 𝒌) **Falso**
#
# O
#
# (∼ 𝒉 ∨ 𝒊) **Verdadero** y (𝒋 ⟹ 𝒌) **Verdadero**
#
# o
#
# (∼ 𝒉 ∨ 𝒊) **Falso** y (𝒋 ⟹ 𝒌) **Verdadero**
# }
#
# ⟹
#
# (𝒋 ⟹ 𝒌) **Verdadero** <=> (∼ 𝒉 ∨ 𝒊) **Falso o Verdadero** <=> h **Falso o Verdadero** *v* i **Verdadero o Falso**
#
#
# ∴ (i *v* \~i) => (𝒋 ⟹ 𝒌)  *v*  (~h *v* h) => (𝒋 ⟹ 𝒌)
#
# ∴ (𝒋 ⟹ 𝒌)
#
#     2. (∼ 𝒍 ∧∼ 𝒎) ⟹ (𝒌 ⟹ 𝒏)
#
# (∼ 𝒍 ∧∼ 𝒎) ⟹ (𝒌 ⟹ 𝒏) **Vedadero**
#
# <=>
#
# {
# (∼ 𝒍 ∧∼ 𝒎) **Falso** y (𝒌 ⟹ 𝒏) **Falso**
#
# O
#
# (∼ 𝒍 ∧∼ 𝒎) **Verdadero** y (𝒌 ⟹ 𝒏) **Verdadero**
#
# o
#
# (∼ 𝒍 ∧∼ 𝒎) **Falso** y (𝒌 ⟹ 𝒏) **Verdadero**
# }
#
# ⟹
#
# (𝒌 ⟹ 𝒏) **Verdadero** <=> (∼ 𝒍 ∧∼ 𝒎) **Falso o Verdadero** <=> l **Verdadero O Falso** *v* m **Verdadero o Falso**
#
# ∴ (𝒌 ⟹ 𝒏) **Verdadero**
#
# **SI (𝒋 ⟹ 𝒌) y (𝒌 ⟹ 𝒏) ⟹ (𝒋 ⟹ 𝒌 ⟹ 𝒏)**
#
# ∴ 𝒋 ⟹ 𝒏
#
# Utilizar las reglas de inferencia y/o equivalencia
